# %% [markdown]
# # SpaceX Falcon 9 Data Collection (Static Dataset)
# This notebook loads the IBM static SpaceX launch dataset, cleans it, and prepares a dataframe for analysis.

# %%
import requests
import pandas as pd
import datetime

url="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/API_call_spacex_api.json"
data=requests.get(url).json()
df=pd.json_normalize(data)
df=df[['rocket','payloads','launchpad','cores','flight_number','date_utc']]
df=df[df['cores'].map(len)==1]
df=df[df['payloads'].map(len)==1]
df['cores']=df['cores'].map(lambda x:x[0])
df['payloads']=df['payloads'].map(lambda x:x[0])
df['date']=pd.to_datetime(df['date_utc']).dt.date
df=df[df['date']<=datetime.date(2020,11,13)]
df.head()

# %% [markdown]
# ## Save cleaned dataset

# %%
df.to_csv('dataset_part_1.csv',index=False)
print(df.shape)
